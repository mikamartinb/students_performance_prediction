# %% [markdown]
# # Import requirements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read data

# %%
path = "../data/StudentsPerformance.csv"
train_data = pd.read_csv(path)

# %% [markdown]
# # Basic EDA

# %%
train_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
train_data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Math score visualizations by gender

# %%
# === Gender Bar Plot ===
gender_means = (
    train_data
    .groupby("gender")[["math score", "reading score", "writing score"]]
    .mean()
)

scores = gender_means.columns
x = np.arange(len(scores))

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(18,4))


genders = list(gender_means.index)
n = len(genders)
bar_w = 0.8 / n

for i, g in enumerate(genders):
    offset = (i - (n-1)/2) * bar_w
    ax1.bar(x + offset, gender_means.loc[g], bar_w, label=g.title())

ax1.set_xticks(x)
ax1.set_xticklabels(["Math", "Reading", "Writing"])
ax1.set_ylim(0, 100)
ax1.set_ylabel("Mean Score")
ax1.set_title("Mean Scores by Gender")
ax1.legend()

# === Ethnicity Bar Plot ===
ethnicity_means = (
    train_data
    .groupby("race/ethnicity")[["math score", "reading score", "writing score"]]
    .mean()
)

groups = list(ethnicity_means.index)
n = len(groups)
bar_w = 0.8 / n

for i, g in enumerate(groups):
    offset = (i - (n-1)/2) * bar_w
    ax2.bar(x + offset, ethnicity_means.loc[g], bar_w, label=g.title())

ax2.set_xticks(x)
ax2.set_xticklabels(["Math", "Reading", "Writing"])
ax2.set_ylim(0, 100)
ax2.set_ylabel("Mean Score")
ax2.set_title("Mean Scores by Ethnicity")
ax2.legend(ncol=2, fontsize=8)

# === Parental Level of Education Bar Plot ===
parent_means = (
    train_data
    .groupby("parental level of education")[["math score", "reading score", "writing score"]]
    .mean()
)

groups = list(parent_means.index)
n = len(groups)
bar_w = 0.8 / n

for i, g in enumerate(groups):
    offset = (i - (n-1)/2) * bar_w
    ax3.bar(x + offset, parent_means.loc[g], bar_w, label=g.title())

ax3.set_xticks(x)
ax3.set_xticklabels(["Math", "Reading", "Writing"])
ax3.set_ylim(0, 100)
ax3.set_ylabel("Mean Score")
ax3.set_title("Mean Scores by Parental Level of Education")
ax3.legend(ncol=2, fontsize=8)

# === Lunch Bar Plot ===
lunch_means = (
    train_data
    .groupby("lunch")[["math score", "reading score", "writing score"]]
    .mean()
)

groups = list(lunch_means.index)
n = len(groups)
bar_w = 0.8 / n

for i, g in enumerate(groups):
    offset = (i - (n-1)/2) * bar_w
    ax4.bar(x + offset, lunch_means.loc[g], bar_w, label=g.title())

ax4.set_xticks(x)
ax4.set_xticklabels(["Math", "Reading", "Writing"])
ax4.set_ylim(0, 100)
ax4.set_ylabel("Mean Score")
ax4.set_title("Mean Scores by Lunch")
ax4.legend(ncol=2, fontsize=8)

# === Test Preparation Course Bar Plot ===
test_means = (
    train_data
    .groupby("test preparation course")[["math score", "reading score", "writing score"]]
    .mean()
)

groups = list(test_means.index)
n = len(groups)
bar_w = 0.8 / n

for i, g in enumerate(groups):
    offset = (i - (n-1)/2) * bar_w
    ax5.bar(x + offset, test_means.loc[g], bar_w, label=g.title())

ax5.set_xticks(x)
ax5.set_xticklabels(["Math", "Reading", "Writing"])
ax5.set_ylim(0, 100)
ax5.set_ylabel("Mean Score")
ax5.set_title("Mean Scores by Test Preparation Course")
ax5.legend(ncol=2, fontsize=8)


plt.tight_layout()
plt.show()
